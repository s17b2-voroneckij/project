# %%
from main import *

# %%
f = open('Lorenz_z_5_0_100_5000')
readpoints(f)
set_params(10, 1)
clusters, cluster, g = Wishart()
plot(clusters, a=0, b=1)

# %%
plot(clusters, 0, 2)

# %%
plot(clusters, 0, 3)

# %%
plot(clusters, 1, 2)
