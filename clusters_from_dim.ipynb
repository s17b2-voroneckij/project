# %%
from main import *

# %%
def num_clusters(LSADict, filenames, z=3, dim=5, k=5, h=0.5):
    clusters, cluster, g = make_paths(LSADict, filenames, z, dim, k, h)
    return len(set(cluster)), cluster.count(0) / len(cluster)

# %%
def draw(LSADict, filenames, z, k, h, dim):
    nc = []
    trash = []
    for d in dim:
        num, tr = num_clusters(LSADict, filenames, z, d, k, h)
        nc.append(num)
        trash.append(tr)
    plt.plot(dim, nc)
    return trash
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
LSA_DICT = LSADict(open('ruscorpora_upos_skipgram_300_5_2018.vec'))

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 5, 0.7, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.0,
#  0.9776714513556619,
#  0.9170653907496013,
#  0.9617224880382775,
#  0.9760765550239234,
#  0.9457735247208932]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 1.0, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.0,
#  0.9872408293460925,
#  0.9712918660287081,
#  0.9744816586921851,
#  0.9760765550239234,
#  0.6347687400318979]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 2, 0, [1, 2, 3, 5, 10, 20, 50])
# Out:
# /home/dima/Yandex.Disk/Wishart/main.py:94: RuntimeWarning: divide by zero encountered in double_scalars
#   prob[vec[1]] = K / n / volume(v_sorted[K][0])
# /home/dima/Yandex.Disk/Wishart/main.py:117: RuntimeWarning: invalid value encountered in double_scalars
#   self.is_meaningful = (self.max_prob - self.min_prob) >= H
# [0.4784688995215311,
#  0.7161084529505582,
#  0.7543859649122807,
#  0.8070175438596491,
#  0.7878787878787878,
#  0.7639553429027113,
#  0.7304625199362041]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 0, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.9090909090909091,
#  0.9457735247208932,
#  0.9840510366826156,
#  0.9840510366826156,
#  0.9681020733652312,
#  0.9808612440191388,
#  0.9824561403508771]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 0.2, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.9409888357256778,
#  0.9872408293460925,
#  0.9712918660287081,
#  0.9744816586921851,
#  0.9760765550239234,
#  0.6347687400318979]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 0.4, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.0,
#  0.9872408293460925,
#  0.9712918660287081,
#  0.9744816586921851,
#  0.9760765550239234,
#  0.6347687400318979]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 0.6, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.0,
#  0.9872408293460925,
#  0.9712918660287081,
#  0.9744816586921851,
#  0.9760765550239234,
#  0.6347687400318979]

# %%
draw(LSA_DICT, ['1.1.1.txt'], 3, 7, 0.9, [1, 2, 3, 5, 10, 20, 50])
# Out:
# [0.0,
#  0.0,
#  0.9872408293460925,
#  0.9712918660287081,
#  0.9744816586921851,
#  0.9760765550239234,
#  0.6347687400318979]
