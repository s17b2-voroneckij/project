# %%
from main import *

# %%
f = open('testingdata/data_1_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 1)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_2_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 1)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_3_dim_2.txt')
readpoints(f)
f.close()
set_params(4, 1)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_4_dim_2.txt')
readpoints(f)
f.close()
set_params(4, 1)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_5_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 1)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_6_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 0.7 * 2)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_7_dim_2.txt')
readpoints(f)
f.close()
set_params(3, 0.7 * 2)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_8_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 0.7 * 2)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_9_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 0.7 * 2)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_10_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 0.3)
clusters, cluster, g = Wishart()
plot(clusters)

# %%
f = open('testingdata/data_15_dim_2.txt')
readpoints(f)
f.close()
set_params(5, 1)
clusters, cluster, g = Wishart()
plot(clusters)
